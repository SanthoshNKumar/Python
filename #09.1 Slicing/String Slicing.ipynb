# %%
s = 'mysore'

# %%
id(s) # Get the adddress of the string 's'
# Out:
# 2818711847344

# %%
id(s[0])
# Out:
# 2818638615280

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = 'mybacon'

# %%
s[2:5]
# Out:
# 'bac'

# %%
s[2:7]
# Out:
# 'bacon'

# %%
s[0:2]
# Out:
# 'my'

# %%
# omit the first or last index:

s = 'mybacon'

s[:2]
# Out:
# 'my'

# %%
s[:5]
# Out:
# 'mybac'

# %%
s[2:]
# Out:
# 'bacon'

# %%
s[2:len(s)]
# Out:
# 'bacon'

# %%
s[:2] + s[2:]
# Out:
# 'mybacon'

# %%
# negative index slicing:

s = 'mybacon'

s[-5:-1]
# Out:
# 'baco'

# %%
s[2:6]
# Out:
# 'baco'

# %%
# slice with a stride:

s = 'mybacon'

s[0:7:2]
# Out:
# 'mbcn'

# %%
s[1:7:2]
# Out:
# 'yao'

# %%
# Reverse a String using Slicing
# We can reverse a string using slicing by providing the step value as -1.

s[::-1]
# Out:
# 'nocabym'

# %%
s1 = s[8:1:-1]
print(s1)
# Out:
# nocab

# %%
a = "my name is santhosh"

a.split()
# Out:
# ['my', 'name', 'is', 'santhosh']

# %%
a = "my@name@is@santhosh"

a.split('@')
# Out:
# ['my', 'name', 'is', 'santhosh']

# %%
a.split('a')
# Out:
# ['my@n', 'me@is@s', 'nthosh']

# %%
type(a.split('a'))
# Out:
# list

# %%
a.partition("a")
# Out:
# ('my@n', 'a', 'me@is@santhosh')

# %%
a.partition("a")   # The saperator is mandotory # splitting based only on the first occurence of the saperator
# Out:
# ('my@n', 'a', 'me@is@santhosh')

# %%
type(a.partition("a"))
# Out:
# tuple

# %%
d = "asdadasdsadadad"

d.find('d') # It gives the index of the first occurence of the delimeter
# Out:
# 2

# %%
d.find('ad')
# Out:
# 3

# %%
d.find('z') # if charter not available in the string then it will return -1
# Out:
# -1

# %%
f = "santhosh"

# %%
f.center(50,'b')
# Out:
# 'bbbbbbbbbbbbbbbbbbbbbsanthoshbbbbbbbbbbbbbbbbbbbbb'

# %%
f.center(50,)
# Out:
# '                     santhosh                     '

# %%
'santhosh\tkumar\tasda\tasfdsada'.split('\t')
# Out:
# ['santhosh', 'kumar', 'asda', 'asfdsada']

# %%
'santhosh\tkumar\tasda\tasfdsada'.expandtabs()
# Out:
# 'santhosh        kumar   asda    asfdsada'

# %%
'my name is {} Kumar'.format('Santhosh')
# Out:
# 'my name is Santhosh Kumar'

# %%
a = input("Please give your First name ")
b = input("Please give your last name ")

'my name is {0} {1}'.format(a,b)
# Out:
# Please give your First name Santhosh
# Please give your last name Kumar
# 'my name is Santhosh Kumar'

# %%
s = "asdsad"
