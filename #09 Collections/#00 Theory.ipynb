# %%
'''
What are Data Structure?
    Storing and Organizing the data in such a way that it can be efficiently accessed

Why are Data Structures needed?
    
Types of Data Structures
    Built In Data Structures
        - List
        - Dictionaries
        - Tuples
        - Sets
    User Defined Data Structures
        - Array
        - Stack
        - Queue
        - Linked List
        - Tree
        - Graph
        
Types of Data Structures
    - Linear data Structures
        - data is arranged sequentially in which items are linked one after the other
        - all the data item in the linear data structure can traversed in single run
        - Array, Stack,Queue etc
    - Non Linear data Structures
        - Every item attched to many othe item
        - Can not be traversed in one run
        - trees,Graph etc
        
Difference Between Array and  list
    - Arrays have only in datatypes(List of datatype integer takes only integer values taken into the array) list 
      are mutable (it can takes values of different data types)
    
Stack : Stacks are made from arrys and it Generally follow the LIFO principle (Last in first Out)
         - Leaving the most recently added data on the top
         - Inservation of item (Push)
         - Removal of Item(Pop)
         - Example : Pile of dinner plates

Queues : Queues are made from arrys and it Generally follow the FIFO principle (First in first Out)
         - People standing in a queue to board a bus
         
Linked List : 
    - Sequence of nodes
    - Each node is connected to following node
    - Each node contains data field and reference to the next node
    - Elements are linked using pointers
    - Dynamic data structures which can grow or shrink anytime
    - No need to specify initial size
    - No memory wastage as it can shrink
    
Single Linked list:
    - Nodes with a data field and a pointer to next node
    - Traversal allowed one way
   
Doubly linked list:
    - Nodes with a data field and a pointer to previous and next node
    - Traversal possible in both directions
Linear Search
    - Each element is checked and compared with target key
    - proces is repeated until element is found or file ends
    - Time Consuming

Binary Search

Bubble Sort

Selection Sort

Inersation Sort

Selection Sort

Merge Sort

Quick Sort

Hear Sort

'''
